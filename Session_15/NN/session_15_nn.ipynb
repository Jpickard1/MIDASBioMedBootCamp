# %% [markdown]
# # Planar data classification with one hidden layer
#
# Welcome to your day3 programming section. It's time to build your first neural network, which will have a hidden layer. You will see a big difference between this model and the one you implemented using logistic regression.
#
# **You will learn how to:**
# - Implement a 2-class classification neural network with a single hidden layer
# - Use units with a non-linear activation function, such as tanh
# - Compute the cross entropy loss
# - Implement forward and backward propagation
#
# Reference:
# - http://scs.ryerson.ca/~aharley/neural-networks/
# - http://cs231n.github.io/neural-networks-case-study/

# %% [markdown]
# ## 1 - import python files ##
#
# Let's first import all the packages that you will need during this assignment.
# - [numpy](www.numpy.org) is the fundamental package for scientific computing with Python.
# - [sklearn](http://scikit-learn.org/stable/) provides simple and efficient tools for data mining and data analysis.
# - [matplotlib](http://matplotlib.org) is a library for plotting graphs in Python.
# - testCases provides some test examples to assess the correctness of your functions
# - planar_utils provide various useful functions used in this assignment

# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt

import sklearn
# Dataset
import sklearn.datasets
# Model
import sklearn.linear_model
from planar_utils import plot_decision_boundary, sigmoid, load_planar_dataset, load_extra_datasets
from keras.models import Sequential
from keras.layers import Dense

# Split train and test sets
from sklearn.model_selection import train_test_split

# This is how we usually import written py files to use the functions/classes in those files
from testCases import *

# Visualization
# %matplotlib inline
from mlxtend.plotting import plot_decision_regions

np.random.seed(1) # set a seed so that the results are consistent

# %% [markdown]
# ## 2 - Dataset ##
#
# First, let's get the dataset you will work on. The following code will load a "flower" 2-class dataset into variables `X` and `Y`.

# %%
X, Y = load_planar_dataset()

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data.

# %%
# Visualize the data:
# c: carray-like or list of colors or color, optional
# camp: str or Colormap, default: rcParams["image.cmap"] (default: 'viridis')
# A Colormap instance or registered colormap name. cmap is only used if c is an array of floats.
plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral);
plt.show()

# %% [markdown]
# You have:
#     - a numpy-array (matrix) X that contains your features (x1, x2)
#     - a numpy-array (vector) Y that contains your labels (red:0, blue:1).
#
# Lets first get a better sense of what our data is like.
#
# **Exercise**: How many training examples do you have? In addition, what is the `shape` of the variables `X` and `Y`?
#
# **Hint**: How do you get the shape of a numpy array? [(help)](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.shape.html)

# %%
### START CODE HERE ### (≈ 3 lines of code)
shape_X = X.shape
shape_Y = Y.shape
m = shape_Y[1]  # training set size
### END CODE HERE ###

print ('The shape of X is: ' + str(shape_X))
print ('The shape of Y is: ' + str(shape_Y))
print ('The dataset has m = %d examples!' % (m))
# Out:
# The shape of X is: (2, 400)
# The shape of Y is: (1, 400)
# The dataset has m = 400 examples!

# %% [markdown]
# **Expected Output**:
#
# <table style="width:20%">
#
#   <tr>
#     <td>**shape of X**</td>
#     <td> (2, 400) </td>
#   </tr>
#
#   <tr>
#     <td>**shape of Y**</td>
#     <td>(1, 400) </td>
#   </tr>
#
#     <tr>
#     <td>**m**</td>
#     <td> 400 </td>
#   </tr>
#
# </table>

# %% [markdown]
# **Cross validation**
#
# Try to split the dataset into training and test set with the function train_test_split with test_size = 0.2 and random_state = 0.
#
# Remenber to transpose the matrix before you input it into the function.

# %%
# Solution:
X = X.T
Y = Y.T
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0) # Leave this line blank for exercise

# %% [markdown]
# ## 3 - Simple Logistic Regression
#
# Before building a full neural network, lets first see how logistic regression performs on this problem. You can use sklearn's built-in functions to do that. Run the code below to train a logistic regression classifier on the dataset.

# %%
# Train the logistic regression classifier
clf = sklearn.linear_model.LogisticRegressionCV();
# ravel(): expand dimension
# https://numpy.org/doc/stable/reference/generated/numpy.ravel.html
clf.fit(X_train, np.ravel(y_train));

# %% [markdown]
# You can now plot the decision boundary of these models. Run the code below.

# %%
# Plot the decision boundary for logistic regression
plot_decision_boundary(lambda x: clf.predict(x), X.T, Y.T) # Dimensional purpose
plt.title("Logistic Regression")

# Print accuracy
LR_predictions = clf.predict(X_test)
accuracy_socre = clf.score(X_test, y_test)

# To print a number, we need to first convert it to a string by using 
print ('Accuracy of logistic regression: %d '+ str(accuracy_socre*100)+
       '% ' + "(percentage of correctly labelled datapoints)")
# Out:
# Accuracy of logistic regression: %d 51.24999999999999% (percentage of correctly labelled datapoints)

# %% [markdown]
# **Expected Output**:
#
# <table style="width:20%">
#   <tr>
#     <td>**Accuracy**</td>
#     <td> 51.24999999999999% </td>
#   </tr>
#
# </table>

# %% [markdown]
# **Interpretation**: The dataset is not linearly separable, so logistic regression doesn't perform well. Hopefully a neural network will do better. Let's try this now!
#
#
# **Extended reading**:
# Proof that the decision boundary of logistics regression is linear:https://homes.cs.washington.edu/~marcotcr/blog/linear-classifiers/

# %% [markdown]
# ## 4 - Neural Network model
#
# Logistic regression did not work well on the "flower dataset". You are going to train a Neural Network with a single hidden layer.
#
# **Here is our model**:
# <img src="images/classification_kiank.png" style="width:600px;height:300px;">
#
#
# **Reminder**: The general methodology to build a Neural Network is to:
#
#     1. Define the neural network structure ( # of input units,  # of hidden units, etc)
#     2. Compile the model
#     3. Fit the model
#     4. Evaluate the model
#
# Steps 3-4 are like what we did in Tuesday's lab section.

# %% [markdown]
# ### 4.1 - 4.2  - Defining the neural network structure and compile the model ####

# %%
# Step 1: Define the neural network structure ( # of input units,  # of hidden units, etc).
def build_model(input_dim, #int
                first_hidden_layer_node_num = 4, #int
                activation_function='sigmoid' #str
               ):
    # define the keras model
    # https://keras.io/api/models/sequential/
    model = Sequential()
    # The model expects rows of data with 2 variables (the input_dim=2 argument)
    # The first hidden layer has 12 nodes and uses the relu activation function
    model.add(Dense(first_hidden_layer_node_num, input_dim=input_dim, activation='tanh'))
    # The output layer has one node and uses the sigmoid activation function
    model.add(Dense(1, activation=activation_function))
    # compile the keras model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# **To help understand adam greadient decent method, an illustration is as below**

# %% [markdown]
# **Illustration**: The gradient descent algorithm with a good learning rate (converging) and a bad learning rate (diverging). Images courtesy of Adam Harley.
#
# <img src="images/sgd.gif" style="width:400;height:400;"> <img src="images/sgd_bad.gif" style="width:400;height:400;">

# %% [markdown]
# ### 4.3 - Fit the model ####
# Now we fit the model with training data

# %%
# fit the keras model on the dataset
model = build_model(input_dim = 2, first_hidden_layer_node_num = 4, activation_function='sigmoid')
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
#
# Epoch 150/150
# 32/32 [==============================] - 0s 747us/step - loss: 0.3454 - accuracy: 0.8787

# %% [markdown]
# ### 4.4 - Evaluate the model ####
#
# It is time to run the model and see how it performs on a planar dataset. Run the following code to test your model with a single hidden layer of $1$ hidden units.

# %% [markdown]
# Details:
#
# - %.2f stands for "print a float with 2 decimal places"
# - %% prints a literal %

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X_test, y_test)
print("%.2f%%" % (100 * accuracy))
# Out:
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8375
# 83.75%

# %% [markdown]
# **Expected Output**:
#
# <table style="width:40%">
#   <tr>
#     <td>**Accuracy on test set**</td>
#     <td> around 80% percent </td>
#   </tr>
#
# </table>

# %%
# Plot decision boundary
plot_decision_regions(X_test, y_test.reshape(-1), clf=model)
plt.show()

# %% [markdown]
# Accuracy is really high compared to Logistic Regression. The model has learnt the leaf patterns of the flower! Neural networks are able to learn even highly non-linear decision boundaries, unlike logistic regression.
#
# Now, let's try out several hidden layer sizes.

# %% [markdown]
# ### 4.6 - Tuning hidden layer size (optional/ungraded exercise) ###
#
# Run the following code. It may take 1-2 minutes. You will observe different behaviors of the model for various hidden layer sizes.

# %% [markdown]
# **Interpretation**:
# - The larger models (with more hidden units) are able to fit the training set better, until eventually the largest models overfit the data.
# - The best hidden layer size seems to be around n_h = 5. Indeed, a value around here seems to  fits the data well without also incurring noticable overfitting.
# - You might want to consider regularization, which lets you use very large models (such as n_h = 50) without much overfitting.

# %%
# Set plot size
plt.figure(figsize=(16, 32))
# https://www.geeksforgeeks.org/enumerate-in-python/
hidden_layer_sizes = [1, 2, 3, 4, 5, 20, 100]
for i, n_h in enumerate(hidden_layer_sizes):
    # Set plot location
    plt.subplot(5, 2, i+1)
    plt.title('Hidden Layer of size %d' % n_h)
    model_i = build_model(input_dim = 2, first_hidden_layer_node_num = n_h, activation_function='sigmoid')
    model_i.fit(X_train, y_train, epochs=150, batch_size=10)
    plot_decision_regions(X, Y.reshape(-1), clf=model_i)
#     _, accuracy = model_i.evaluate(X_test, y_test)
#     print ("Accuracy for {} hidden units: {} %".format(n_h, accuracy))
# Out:
# Epoch 1/150
# 32/32 [==============================] - 0s 806us/step - loss: 0.7474 - accuracy: 0.4737
# Epoch 2/150
# 32/32 [==============================] - 0s 834us/step - loss: 0.7378 - accuracy: 0.4937
# Epoch 3/150
# 32/32 [==============================] - 0s 837us/step - loss: 0.7607 - accuracy: 0.4519
# Epoch 4/150
# 32/32 [==============================] - 0s 863us/step - loss: 0.7931 - accuracy: 0.4191
# Epoch 5/150
# 32/32 [==============================] - 0s 837us/step - loss: 0.7773 - accuracy: 0.4270
# Epoch 6/150
# 32/32 [==============================] - 0s 796us/step - loss: 0.7779 - accuracy: 0.4198
# Epoch 7/150
# 32/32 [==============================] - 0s 806us/step - loss: 0.7273 - accuracy: 0.4974
# Epoch 8/150
# 32/32 [==============================] - 0s 839us/step - loss: 0.7550 - accuracy: 0.4272
# Epoch 9/150
# 32/32 [==============================] - 0s 805us/step - loss: 0.7363 - accuracy: 0.4500
# 32/32 [==============================] - 0s 713us/step - loss: 0.6202 - accuracy: 0.5553
# Epoch 131/150
# 32/32 [==============================] - 0s 752us/step - loss: 0.6075 - accuracy: 0.5572
# Epoch 132/150
# 32/32 [==============================] - 0s 731us/step - loss: 0.5803 - accuracy: 0.5834
# Epoch 133/150
# 32/32 [==============================] - 0s 733us/step - loss: 0.5988 - accuracy: 0.5602
# Epoch 134/150
# 32/32 [==============================] - 0s 706us/step - loss: 0.5919 - accuracy: 0.5517
# Epoch 135/150
# 32/32 [==============================] - 0s 673us/step - loss: 0.5616 - accuracy: 0.6071
# Epoch 136/150
# 32/32 [==============================] - 0s 701us/step - loss: 0.6003 - accuracy: 0.6017
# Epoch 137/150
# 32/32 [==============================] - 0s 752us/step - loss: 0.6004 - accuracy: 0.5422
# Epoch 138/150
# 32/32 [==============================] - 0s 712us/step - loss: 0.5933 - accuracy: 0.5739
# Epoch 139/150
# 32/32 [==============================] - 0s 692us/step - loss: 0.6215 - accuracy: 0.5645
# Epoch 140/150
# 32/32 [==============================] - 0s 682us/step - loss: 0.6199 - accuracy: 0.5193
# Epoch 141/150
# 32/32 [==============================] - 0s 694us/step - loss: 0.5901 - accuracy: 0.5742
# Epoch 142/150
# 32/32 [==============================] - 0s 796us/step - loss: 0.6328 - accuracy: 0.5048
# Epoch 143/150
# 32/32 [==============================] - 0s 834us/step - loss: 0.5883 - accuracy: 0.5987
# Epoch 144/150
# 32/32 [==============================] - 0s 845us/step - loss: 0.6315 - accuracy: 0.5157
# Epoch 145/150
# 32/32 [==============================] - 0s 740us/step - loss: 0.5882 - accuracy: 0.5953
# Epoch 146/150
# 32/32 [==============================] - 0s 692us/step - loss: 0.5961 - accuracy: 0.5653
# Epoch 147/150
# 32/32 [==============================] - 0s 676us/step - loss: 0.5971 - accuracy: 0.5660
# Epoch 148/150
# 32/32 [==============================] - 0s 704us/step - loss: 0.6250 - accuracy: 0.5840
# Epoch 149/150
# 32/32 [==============================] - 0s 724us/step - loss: 0.5518 - accuracy: 0.5998
# Epoch 150/150
# 32/32 [==============================] - 0s 709us/step - loss: 0.6083 - accuracy: 0.5610

# %% [markdown]
# **Optional Section**
#
# Some optional/ungraded questions that you can explore if you wish:
# - What happens when you change the tanh activation for a sigmoid activation or a ReLU activation?
# - Play with the learning_rate. What happens?
# - What if we change the dataset? (See part 5 below!)

# %% [markdown]
# ## 5) Performance on other datasets

# %% [markdown]
# If you want, you can rerun the whole notebook (minus the dataset part) for each of the following datasets.

# %%
# Datasets
noisy_circles, noisy_moons, blobs, gaussian_quantiles, no_structure = load_extra_datasets()

datasets = {"noisy_circles": noisy_circles,
            "noisy_moons": noisy_moons,
            "blobs": blobs,
            "gaussian_quantiles": gaussian_quantiles}

### START CODE HERE ### (choose your dataset)
dataset = "noisy_moons"
### END CODE HERE ###

X, Y = datasets[dataset]
X, Y = X.T, Y.reshape(1, Y.shape[0])

# make blobs binary
if dataset == "blobs":
    Y = Y%2

# Visualize the data
plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral);

# %% [markdown]
# Congrats on finishing this Programming Assignment!
